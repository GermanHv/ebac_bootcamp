# %% [markdown]
# # Variables

# %%
# Ejemplos de asignaciones
x = 2
print(x)
# Out:
# 2

# %%
x = x + 3
print(x)
# Out:
# 5

# %%
y = x ** 2
print(y)
# Out:
# 25

# %%
z =23 % 5
print(z)
# Out:
# 3

# %%
x = 1 + 2 + 3 * 5 / 2
print(x)
# Out:
# 10.5

# %%
y = 1 + 2 ** 3 / 4 * 5
print(y)
# Out:
# 11.0

# %%
w = (1 + 2) ** 3 / 4 * 5
print(w)
# Out:
# 33.75

# %% [markdown]
# ## Tipos de expresiones

# %%
type(w)
# Out:
# float

# %%
texto = "Hola, soy un texto"
print(texto)
type(texto)
# Out:
# Hola, soy un texto
# str

# %%
texto2 = "hola" + " " + "mundo"
print(texto2)
# Out:
# hola mundo

# %%
x = 10
y = 15
z = x / y
print(z)
type(z)
# Out:
# 0.6666666666666666
# float

# %%
z = int(z)
print(z)
type(z)
# Out:
# 0
# int

# %%
type(x)
x = float(x)
print(x)
type(x)
# Out:
# 10.0
# float

# %%
nombre = input("¿Cuál es tu nombre? ")
print("Hola, " + nombre + "!")
# Out:
# Hola, Germán!

# %%
edad = input("¿Cuál es tu edad? ")
resultado = int(edad) + 10
print("Tienes " + edad + " años.")
print("En 10 años tendrás " + str(resultado) + " años.")
# Out:
# Tienes 25 años.
# En 10 años tendrás 35 años.
