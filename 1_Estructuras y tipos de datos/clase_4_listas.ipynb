# %% [markdown]
# ## Listas
# Colección de objetos de diversa índole
# las listas son mutables

# %%
amigos = ['Pedro','Juan','José']
amigos
# Out:
# ['Pedro', 'Juan', 'José']

# %%
elementos = ['rojo', 15, [1,2,3], 'verde', 3.14]
elementos
# Out:
# ['rojo', 15, [1, 2, 3], 'verde', 3.14]

# %%
print(elementos[0])
print(elementos[1])
print(elementos[2])
print(elementos[3])
# Out:
# rojo
# 15
# [1, 2, 3]
# verde

# %%
amigos_cercanos = amigos
amigos_cercanos[2] = 'María'
print(amigos)
print(amigos_cercanos)
# Out:
# ['Pedro', 'Juan', 'María']
# ['Pedro', 'Juan', 'María']

# %%
a = [1,2,3]
b = [4,5,6]
c = a + b
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
c[1:3]
c[2:]
# Out:
# [3, 4, 5, 6]

# %%
type(c[2:])
# Out:
# list

# %%
dir(c)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lista = list()
lista
# Out:
# []

# %%
lista.append(1)
lista.append('hola')
lista
# Out:
# [1, 'hola']

# %%
amigos
# Out:
# ['Pedro', 'Juan', 'María']

# %%
amigos.sort()
amigos
# Out:
# ['Juan', 'María', 'Pedro']

# %%
print(max(c))
# Out:
# 6

# %%
print(sum(c))
# Out:
# 21

# %%
amigos = 'José Claudia Ramiro'
lista_amigos = amigos.split()
lista_amigos
# Out:
# ['José', 'Claudia', 'Ramiro']
